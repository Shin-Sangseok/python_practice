# %%
# 주요 라이브러리 import
import warnings
warnings.filterwarnings(action='ignore')
import time
from IPython.display import Image
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import *

from matplotlib import rc, font_manager
import matplotlib.font_manager as fm
from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import MinMaxScaler

# 디렉토리 및 파일 이름에 맞추어 변경
#font_location = '/Library/Fonts/Arial Unicode.ttf'#윈도우안에있는 폰트파일주소.
# font_location = './NanumGothic.ttf'
#font_name = fm.FontProperties(fname=font_location).get_name()
#rc('font', family=font_name)

# %%
df = pd.read_csv('/Users/hi/csv-data/기계마모.csv', encoding = 'utf-8')
df.tail(5)
# Out:
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Machine failure  \
# 9995                    1604         29.5               14                0
# 9996                    1632         31.8               17                0
# 9997                    1645         33.4               22                0
# 9998                    1408         48.5               25                0
# 9999                    1500         40.2               30                0
#
#       TWF  HDF  PWF  OSF  RNF
# 9995    0    0    0    0    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   UDI                      10000 non-null  int64
#  1   Product ID               10000 non-null  object
#  2   Type                     10000 non-null  object
#  3   Air temperature [K]      10000 non-null  float64
#  4   Process temperature [K]  10000 non-null  float64
#  5   Rotational speed [rpm]   10000 non-null  int64
#  6   Torque [Nm]              10000 non-null  float64
#  7   Tool wear [min]          10000 non-null  int64
#  8   Machine failure          10000 non-null  int64
#  9   TWF                      10000 non-null  int64
#  10  HDF                      10000 non-null  int64
#  11  PWF                      10000 non-null  int64
#  12  OSF                      10000 non-null  int64
#  13  RNF                      10000 non-null  int64
# ...

# %%
df.describe()
# Out:
#                UDI  Air temperature [K]  Process temperature [K]  \
# count  10000.00000         10000.000000             10000.000000
# mean    5000.50000           300.004930               310.005560
# std     2886.89568             2.000259                 1.483734
# min        1.00000           295.300000               305.700000
# 25%     2500.75000           298.300000               308.800000
# 50%     5000.50000           300.100000               310.100000
# 75%     7500.25000           301.500000               311.100000
# max    10000.00000           304.500000               313.800000
#
#        Rotational speed [rpm]   Torque [Nm]  Tool wear [min]  Machine failure  \
# count            10000.000000  10000.000000     10000.000000     10000.000000
# mean              1538.776100     39.986910       107.951000         0.033900
# std                179.284096      9.968934        63.654147         0.180981
# ...

# %%
df.drop(['Product ID','UDI','TWF','HDF','PWF','OSF','RNF'], axis=1, inplace=True)

# %%
df
# Out:
#      Type  Air temperature [K]  Process temperature [K]  \
# 0       M                298.1                    308.6
# 1       L                298.2                    308.7
# 2       L                298.1                    308.5
# 3       L                298.2                    308.6
# 4       L                298.2                    308.7
# ...   ...                  ...                      ...
# 9995    M                298.8                    308.4
# 9996    H                298.9                    308.4
# 9997    M                299.0                    308.6
# 9998    H                299.0                    308.7
# 9999    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Machine failure
# 0                       1551         42.8                0                0
# 1                       1408         46.3                3                0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
encoder.fit(df['Type'])
# Out:
# LabelEncoder()

# %%
tmp = encoder.transform(df['Type'])
tmp
# Out:
# array([2, 1, 1, ..., 2, 0, 2])

# %%
t = pd.Series(tmp)
type(t)
# Out:
# pandas.core.series.Series

# %%
df.head(5)
# Out:
#   Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0    M                298.1                    308.6                    1551
# 1    L                298.2                    308.7                    1408
# 2    L                298.1                    308.5                    1498
# 3    L                298.2                    308.6                    1433
# 4    L                298.2                    308.7                    1408
#
#    Torque [Nm]  Tool wear [min]  Machine failure
# 0         42.8                0                0
# 1         46.3                3                0
# 2         49.4                5                0
# 3         39.5                7                0
# 4         40.0                9                0

# %%
df['Type'] = t
df.head()
# Out:
#    Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0     2                298.1                    308.6                    1551
# 1     1                298.2                    308.7                    1408
# 2     1                298.1                    308.5                    1498
# 3     1                298.2                    308.6                    1433
# 4     1                298.2                    308.7                    1408
#
#    Torque [Nm]  Tool wear [min]  Machine failure
# 0         42.8                0                0
# 1         46.3                3                0
# 2         49.4                5                0
# 3         39.5                7                0
# 4         40.0                9                0

# %%
df.head()
df['Type'].value_counts()
# Out:
# 1    6000
# 2    2997
# 0    1003
# Name: Type, dtype: int64

# %%
df.head()
# Out:
#    Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0     2                298.1                    308.6                    1551
# 1     1                298.2                    308.7                    1408
# 2     1                298.1                    308.5                    1498
# 3     1                298.2                    308.6                    1433
# 4     1                298.2                    308.7                    1408
#
#    Torque [Nm]  Tool wear [min]  Machine failure
# 0         42.8                0                0
# 1         46.3                3                0
# 2         49.4                5                0
# 3         39.5                7                0
# 4         40.0                9                0

# %%
X_df = df.iloc[:,:5]
y_df = df.iloc[:,6:]

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(
    X_df,
    y_df,
    test_size = 0.2, 
    shuffle = True, 
    random_state = 42
)

# %%
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (8000, 5) (8000, 1) (2000, 5) (2000, 1)

# %%
type(X_test)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y_test)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
rf_clf = RandomForestClassifier(random_state = 11)
lr_clf = LogisticRegression()
knn_clf = KNeighborsClassifier(n_neighbors = 5)
knn_clf2 = KNeighborsClassifier(n_neighbors = 10)
svm_svc = SVC(kernel = 'rbf')
svm_svc2 = SVC(kernel = 'linear')

# %%
from sklearn.model_selection import cross_val_score

# %%
clf_list = [rf_clf, lr_clf, knn_clf, knn_clf2, svm_svc, svm_svc2]

for clf in clf_list: 
    scores = cross_val_score(clf, X_train, y_train.values.ravel(), cv = 6)
    for iter_count, accuracy in enumerate(scores):
        print('교차 검증 {0} 정확도:{1:.4f}'.format(iter_count, accuracy))
    print('{0}평균 정확도 : {1:4f}\n'.format(clf, np.mean(scores)))
# Out:
# 교차 검증 0 정확도:0.9850
# 교차 검증 1 정확도:0.9790
# 교차 검증 2 정확도:0.9820
# 교차 검증 3 정확도:0.9775
# 교차 검증 4 정확도:0.9767
# 교차 검증 5 정확도:0.9820
# RandomForestClassifier(random_state=11)평균 정확도 : 0.980375
#
# 교차 검증 0 정확도:0.9768
# 교차 검증 1 정확도:0.9700
# 교차 검증 2 정확도:0.9707
# 교차 검증 3 정확도:0.9685
# 교차 검증 4 정확도:0.9670
# 교차 검증 5 정확도:0.9700
# LogisticRegression()평균 정확도 : 0.970499
#
# 교차 검증 0 정확도:0.9685
# 교차 검증 1 정확도:0.9700
# 교차 검증 2 정확도:0.9670
# 교차 검증 3 정확도:0.9685
# 교차 검증 4 정확도:0.9685
# 교차 검증 5 정확도:0.9722
# KNeighborsClassifier()평균 정확도 : 0.969125
#
# 교차 검증 0 정확도:0.9700
# 교차 검증 1 정확도:0.9700
# 교차 검증 2 정확도:0.9685
# 교차 검증 3 정확도:0.9700
# 교차 검증 4 정확도:0.9677
# 교차 검증 5 정확도:0.9692
# KNeighborsClassifier(n_neighbors=10)평균 정확도 : 0.969250
#
# 교차 검증 0 정확도:0.9648
# 교차 검증 1 정확도:0.9648
# 교차 검증 2 정확도:0.9655
# 교차 검증 3 정확도:0.9655
# 교차 검증 4 정확도:0.9655
# 교차 검증 5 정확도:0.9655
# SVC()평균 정확도 : 0.965250
#
# 교차 검증 0 정확도:0.9738
# 교차 검증 1 정확도:0.9700
# 교차 검증 2 정확도:0.9685
# 교차 검증 3 정확도:0.9692
# 교차 검증 4 정확도:0.9692
# 교차 검증 5 정확도:0.9715
# ...

# %%
from sklearn.model_selection import GridSearchCV

# %%
rf_parameters = {
    'max_depth': [3,4,5,6,7,8],
    'n_estimators': [3,4,5,10],
    'random_state': [10,20,40]
}

# %%
grid_rf = GridSearchCV(
    estimator = rf_clf, 
    param_grid = rf_parameters, 
    scoring = 'accuracy', 
    cv = 10
)
grid_rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(random_state=11),
#              param_grid={'max_depth': [3, 4, 5, 6, 7, 8],
#                          'n_estimators': [3, 4, 5, 10],
#                          'random_state': [10, 20, 40]},
#              scoring='accuracy')

# %%
best_rf = grid_rf.best_estimator_ 
print(best_rf)
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=10, random_state=40)

# %%
dpredictions = best_rf.predict(X_test)
accuracy = accuracy_score(y_test, dpredictions)
print('테스트셋 rf 정확도 : {0:.4f}'.format(accuracy))
# Out:
# 테스트셋 rf 정확도 : 0.9775

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, dpredictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1939
#            1       0.71      0.44      0.55        61
#
#     accuracy                           0.98      2000
#    macro avg       0.85      0.72      0.77      2000
# weighted avg       0.97      0.98      0.97      2000
